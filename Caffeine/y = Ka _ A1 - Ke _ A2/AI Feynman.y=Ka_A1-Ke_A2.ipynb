# %% [markdown]
# Data Visualization

# %%
import jax
import flax
import optax
from jax import lax, random, numpy as jnp
from jax import random, grad, vmap, hessian, jacfwd, jit
from jax import config
from flax import linen as nn
from scipy.integrate import odeint

import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# choose GPU
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
jax.config.update("jax_enable_x64", True)

# %%
# !pip install evojax
from evojax.util import get_params_format_fn
# Out:
# Requirement already satisfied: evojax in /usr/local/lib/python3.10/dist-packages (0.2.17)
# Requirement already satisfied: flax in /usr/local/lib/python3.10/dist-packages (from evojax) (0.8.4)
# Requirement already satisfied: jax>=0.2.17 in /usr/local/lib/python3.10/dist-packages (from evojax) (0.4.26)
# Requirement already satisfied: jaxlib>=0.1.65 in /usr/local/lib/python3.10/dist-packages (from evojax) (0.4.26+cuda12.cudnn89)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from evojax) (9.4.0)
# Requirement already satisfied: cma in /usr/local/lib/python3.10/dist-packages (from evojax) (3.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from evojax) (3.7.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from evojax) (6.0.2)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.2.17->evojax) (0.4.0)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from jax>=0.2.17->evojax) (1.26.4)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax>=0.2.17->evojax) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from jax>=0.2.17->evojax) (1.13.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from flax->evojax) (1.0.8)
# Requirement already satisfied: optax in /usr/local/lib/python3.10/dist-packages (from flax->evojax) (0.2.2)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.10/dist-packages (from flax->evojax) (0.5.23)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.10/dist-packages (from flax->evojax) (0.1.64)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.10/dist-packages (from flax->evojax) (13.7.1)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.10/dist-packages (from flax->evojax) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->evojax) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax->evojax) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax->evojax) (2.16.1)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from optax->flax->evojax) (1.4.0)
# Requirement already satisfied: chex>=0.1.86 in /usr/local/lib/python3.10/dist-packages (from optax->flax->evojax) (0.1.86)
# Requirement already satisfied: etils[epath,epy] in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax->evojax) (1.7.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax->evojax) (1.6.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax->evojax) (3.20.3)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chex>=0.1.86->optax->flax->evojax) (0.12.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax->evojax) (0.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->evojax) (2024.6.1)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->evojax) (6.4.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->evojax) (3.20.0)

# %%
#true params
Ka_true = 2.821 # 1/h - not in spreadsheet
Ke_true = 0.693/6.3 # 1/h
V_blood_true = 19 # L
V_gut_true = 1.3612 # L
dosage_true = 100.5348 #mg, just for reference

# %%
#initial conditions
A1_init = 73.864090508375 # / V_gut_true # (mg/L) #needs to be decided
A2_init = 0 # (mg/L)

# %%
# task array
task_params = np.array([[Ka_true, Ke_true, V_gut_true, V_blood_true]])

n_task = len(task_params)
n_task, task_params
# Out:
# (1, array([[ 2.821 ,  0.11  ,  1.3612, 19.    ]]))

# %% [markdown]
# Obtaining Ground Truth

# %%
#caffeine equation solution generator
def caffeine(y, t, Ka, Ke, V_gut, V_blood):
    """A1 and A2 terms are not divided by V, they are just divided before being plotted"""
    A1_sys, A2_sys = y
    dydt = [-Ka* (A1_sys), Ka*(A1_sys) - Ke*(A2_sys)]
    return dydt

# %%
data_A1, data_A2, data_S = [], [], [] #collect all 6 tasks (different combination of a1 a2) #data S is all zeroes
t = jnp.linspace(0, 24, 201)
t_param = t #copy for calculating ODE
t = np.expand_dims(t, axis=1) #for data_X

data_T = t
for task in task_params:

    y0 = [A1_init * V_gut_true, A2_init * V_blood_true] #must scale A1 and A2 if all resulting A1/A2 values are divided by V

    #get ODE soln for A2
    sol = odeint(caffeine, y0, t_param, args=(Ka_true, Ke_true, V_gut_true, V_blood_true))
    A1_soln = sol[:, 0:1]
    A2_soln = sol[:, 1:2]

    #divide all values by V
    data_A2.append(A2_soln/V_blood_true)
    data_A1.append(A1_soln/V_gut_true)

    #init an array of zeroes for g
    s_array = np.zeros(len(A2_soln))
    s_array = np.expand_dims(s_array, axis=1)
    data_S.append(s_array)

data_A1, data_A2, data_S = jnp.array(data_A1[0]), jnp.array(data_A2[0]), jnp.array(data_S[0])
data_y = Ka_true * data_A1 - Ke_true * data_A2
print (data_T.shape, data_A1.shape, data_A2.shape, data_S.shape, data_y.shape)
# Out:
# (201, 1) (201, 1) (201, 1) (201, 1) (201, 1)

# %%
fig = plt.figure(figsize=(15, 3.5))
ax1 = fig.add_subplot(1,2,1)


params = task_params[0]
plt.plot(data_T, data_A1, label='A1')
plt.plot(data_T, data_y, label='y = Ka * A1 - Ke * A2')

plt.title("A1 vs. time - New Equation"); plt.legend();
plt.xlabel("Time"); plt.ylabel("A1");
ax1 = fig.add_subplot(1,2,2)


params = task_params[0]
plt.plot(data_T, data_A2, label='A2')
plt.plot(data_T, data_y, label='y = Ka * A1 - Ke * A2')

    # plt.plot(data_T, data_A2_csv[0], label='CSV data')
plt.title("A2 vs. time - New Equation"); plt.legend();
plt.xlabel("Time"); plt.ylabel("A2");

# %%
plt.close() #close previous plot

#Plotting A2 vs. Y
fig = plt.figure(figsize=(15, 3.5))
ax1 = fig.add_subplot(1, 2, 1)


plt.plot(data_A1, data_y, label='Data A1 vs. y')
# plt.plot(data_T, data_A1_csv[0], label='CSV data')

plt.title("A1 vs. y=Ka*A1-Ke*A2"); plt.legend();
plt.xlabel("A1"); plt.ylabel("y");
ax2 = fig.add_subplot(1,2,2)

plt.plot(data_A2, data_y, label='Data A2 vs. y')

    # plt.plot(data_T, data_A2_csv[0], label='CSV data')
plt.title("A2 vs. y=Ka*A1-Ke*A2"); plt.legend();
plt.xlabel("A2"); plt.ylabel("y");

# %% [markdown]
# ## AI Feynman

# %%
# Mounting colab notebook to drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# *Installing AI-Feynman and relevant packages*

# %%
# Checking OS version, fortran compiler version, and granting relevant permissions (github only)
# !sudo apt-get install csh
# !lsb_release -a
# !gfortran --version
# !chmod +777 '/content/drive/My Drive/Symbolic-Regressor/Feynman Local/'*
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# csh is already the newest version (20110502-7).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 22.04.3 LTS
# Release:	22.04
# Codename:	jammy
# GNU Fortran (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# Installing AI Feynman 2.0, c shell, and relevant packages
## https://ai-feynman.readthedocs.io/en/latest/
# !pip install aifeynman --no-deps
# !pip install sortedcontainers scikit-learn torch seaborn torchvision openpyxl
# Out:
# Requirement already satisfied: aifeynman in /usr/local/lib/python3.10/dist-packages (2.0.7)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (2.4.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.1+cu121)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.18.1+cu121)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.5)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.6.20)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
# Importing relevant modules
import os
import random
import numpy as np
# import matplotlib as plt
import pandas as pd
import aifeynman
from aifeynman import S_brute_force, S_run_aifeynman

#Configuring plt
# %matplotlib inline
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# *Verifying working directory*

# %%
input_path = '/content/drive/My Drive/Symbolic-Regressor/Feynman Local/'
os.chdir(input_path)
# !pwd
# Out:
# /content/drive/My Drive/Symbolic-Regressor/Feynman Local

# %% [markdown]
# *Perfect data - generation, plotting, brute force test, symbolic regression*

# %%
data = np.stack([data_A1, data_A2, data_y]).transpose()
data = data[0]
print(data.shape)

# Saving data as a .txt file in working directory for use by symbolic regression function
np.save(input_path + 'feynman_data_KaA1-KeA2.npy',data)
np.savetxt(input_path + 'feynman_data_KaA1-KeA2.txt',data,delimiter=' ')
# Printing out generated data with Pandas and plotting it with matplotlib
df=pd.read_csv(input_path + 'feynman_data_KaA1-KeA2.txt',sep=" ",header=None)

#plotting
fig = plt.figure(figsize=(15, 3.5))
ax1 = fig.add_subplot(1,2,1)
plt.plot(df[0], df[2], label='A1 vs y')
plt.xlabel("A1"); plt.ylabel("y");
plt.title("A1 vs. y data"); plt.legend();

ax1 = fig.add_subplot(1,2,2)
plt.plot(df[1], df[2], label='A2 vs y')
plt.xlabel("A2"); plt.ylabel("y");

plt.title("A2 vs. y data"); plt.legend();
print(df, df.shape)

#Running brute force test on perfect data
# !pwd
S_brute_force.brute_force(input_path,"feynman_data_KaA1-KeA2.txt",30,"14ops.txt") #may be difficult with KeA2?
# Out:
# (201, 3)
#                 0         1           2
# 0    7.386409e+01  0.000000  208.370599
# 1    5.265214e+01  1.509122  148.365670
# 2    3.753173e+01  2.565072  105.594861
# 3    2.675354e+01  3.298249   75.108928
# 4    1.907058e+01  3.801602   53.379928
# ..            ...       ...         ...
# 196  1.772178e-11  0.414256   -0.045568
# 197  8.033132e-12  0.408824   -0.044971
# 198  7.997448e-12  0.403463   -0.044381
# 199  7.916035e-12  0.398172   -0.043799
# 200  6.091490e-12  0.392950   -0.043225
#
# [201 rows x 3 columns] (201, 3)
# /content/drive/My Drive/Symbolic-Regressor/Feynman Local
# Trying to solve mysteries with brute force...
# Trying to solve /content/drive/My Drive/Symbolic-Regressor/Feynman Local/feynman_data_KaA1-KeA2.txt

# %%
degrees = [1]
epochs = [50]
for degree in degrees: #50
    for num_epochs in epochs:
        print("Epochs:", num_epochs, "Degree", degree)
        # Printing out a few lines of data (purely for reference)
        # !head -n 1 '/content/drive/My Drive/Symbolic-Regressor/Feynman Local/feynman_data_KaA1-KeA2.txt'
        # Running symbolic regression function on generated dataset
        S_run_aifeynman.run_aifeynman(input_path,"feynman_data_KaA1-KeA2.txt",30,"14ops.txt", polyfit_deg=degrees, NN_epochs=epochs)
# Out:
# Epochs: 50 Degree 1
# 7.386409050837499990e+01 0.000000000000000000e+00 2.083705993241258909e+02
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve /content/drive/My Drive/Symbolic-Regressor/Feynman Local/feynman_data_KaA1-KeA2.txt_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve /content/drive/My Drive/Symbolic-Regressor/Feynman Local/feynman_data_KaA1-KeA2.txt_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 34.07 6.46 -0.109999999958*(x1-(x0*exp(pi)))
# 38.97 6.12 -0.109999999975*(x1-(x0*(exp(pi)+1)))
# 39.55 5.48 -0.109999999991*(x1-(x0*((exp(pi)+1)+1)))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_squared/feynman_data_KaA1-KeA2.txt_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_squared/feynman_data_KaA1-KeA2.txt_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 27.74 27.92 sqrt(0.012099999984*(x0+(x1*(x1+x0))))
# 29.32 27.91 sqrt(0.012099999984*((x1+x0)*(x1+x0)))
# 30.32 27.91 sqrt(0.012099999984*(x0+(x1*(x1*(x0+1)))))
# 34.07 6.46 -0.109999999958*(x1-(x0*exp(pi)))
# 38.97 6.12 -0.109999999975*(x1-(x0*(exp(pi)+1)))
# 39.55 5.48 -0.109999999991*(x1-(x0*((exp(pi)+1)+1)))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_atan/feynman_data_KaA1-KeA2.txt_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_atan/feynman_data_KaA1-KeA2.txt_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 27.74 27.92 sqrt(0.012099999984*(x0+(x1*(x1+x0))))
# 29.32 27.91 sqrt(0.012099999984*((x1+x0)*(x1+x0)))
# 30.32 27.91 sqrt(0.012099999984*(x0+(x1*(x1*(x0+1)))))
# 34.07 6.46 -0.109999999958*(x1-(x0*exp(pi)))
# 38.97 6.12 -0.109999999975*(x1-(x0*(exp(pi)+1)))
# 39.55 5.48 -0.109999999991*(x1-(x0*((exp(pi)+1)+1)))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_cos/feynman_data_KaA1-KeA2.txt_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_cos/feynman_data_KaA1-KeA2.txt_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 27.74 27.92 sqrt(0.012099999984*(x0+(x1*(x1+x0))))
# 29.32 27.91 sqrt(0.012099999984*((x1+x0)*(x1+x0)))
# 30.32 27.91 sqrt(0.012099999984*(x0+(x1*(x1*(x0+1)))))
# 34.07 6.46 -0.109999999958*(x1-(x0*exp(pi)))
# 38.97 6.12 -0.109999999975*(x1-(x0*(exp(pi)+1)))
# 39.55 5.48 -0.109999999991*(x1-(x0*((exp(pi)+1)+1)))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_exp/feynman_data_KaA1-KeA2.txt_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_exp/feynman_data_KaA1-KeA2.txt_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 27.74 27.92 sqrt(0.012099999984*(x0+(x1*(x1+x0))))
# 29.32 27.91 sqrt(0.012099999984*((x1+x0)*(x1+x0)))
# 30.32 27.91 sqrt(0.012099999984*(x0+(x1*(x1*(x0+1)))))
# 34.07 6.46 -0.109999999958*(x1-(x0*exp(pi)))
# 38.97 6.12 -0.109999999975*(x1-(x0*(exp(pi)+1)))
# 39.55 5.48 -0.109999999991*(x1-(x0*((exp(pi)+1)+1)))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_inverse/feynman_data_KaA1-KeA2.txt_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_inverse/feynman_data_KaA1-KeA2.txt_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 27.74 27.92 sqrt(0.012099999984*(x0+(x1*(x1+x0))))
# 29.32 27.91 sqrt(0.012099999984*((x1+x0)*(x1+x0)))
# 30.32 27.91 sqrt(0.012099999984*(x0+(x1*(x1*(x0+1)))))
# 34.07 6.46 -0.109999999958*(x1-(x0*exp(pi)))
# 38.97 6.12 -0.109999999975*(x1-(x0*(exp(pi)+1)))
# 39.55 5.48 -0.109999999991*(x1-(x0*((exp(pi)+1)+1)))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_sin/feynman_data_KaA1-KeA2.txt_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_sin/feynman_data_KaA1-KeA2.txt_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 27.74 27.92 sqrt(0.012099999984*(x0+(x1*(x1+x0))))
# 29.32 27.91 sqrt(0.012099999984*((x1+x0)*(x1+x0)))
# 30.32 27.91 sqrt(0.012099999984*(x0+(x1*(x1*(x0+1)))))
# 34.07 6.46 -0.109999999958*(x1-(x0*exp(pi)))
# 38.97 6.12 -0.109999999975*(x1-(x0*(exp(pi)+1)))
# 39.55 5.48 -0.109999999991*(x1-(x0*((exp(pi)+1)+1)))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_squared/feynman_data_KaA1-KeA2.txt_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_squared/feynman_data_KaA1-KeA2.txt_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 27.74 27.92 sqrt(0.012099999984*(x0+(x1*(x1+x0))))
# 29.32 27.91 sqrt(0.012099999984*((x1+x0)*(x1+x0)))
# 30.32 27.91 sqrt(0.012099999984*(x0+(x1*(x1*(x0+1)))))
# 34.07 6.46 -0.109999999958*(x1-(x0*exp(pi)))
# 38.97 6.12 -0.109999999975*(x1-(x0*(exp(pi)+1)))
# 39.55 5.48 -0.109999999991*(x1-(x0*((exp(pi)+1)+1)))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_tan/feynman_data_KaA1-KeA2.txt_train
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_tan/feynman_data_KaA1-KeA2.txt_train
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 27.74 27.92 sqrt(0.012099999984*(x0+(x1*(x1+x0))))
# 29.32 27.91 sqrt(0.012099999984*((x1+x0)*(x1+x0)))
# 30.32 27.91 sqrt(0.012099999984*(x0+(x1*(x1*(x0+1)))))
# 34.07 6.46 -0.109999999958*(x1-(x0*exp(pi)))
# 38.97 6.12 -0.109999999975*(x1-(x0*(exp(pi)+1)))
# 39.55 5.48 -0.109999999991*(x1-(x0*((exp(pi)+1)+1)))
#
# NN already trained
#
# NN loss:  tensor(0.0020, grad_fn=<DivBackward0>)
#
# Checking for symmetries...
#
# Checking for separabilities...
#
# Checking for compositionality...
#
# Checking for generalized symmetry...
#
# Additive separability found for variables: (0,) [1]
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/separable_add/feynman_data_KaA1-KeA2.txt_train-add_a
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/separable_add/feynman_data_KaA1-KeA2.txt_train-add_a
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 46.28 8.18 -0.053521512629*pi
# 49.69 6.3 -0.168142795563+(x0-sin(x0))
# 54.77 5.99 -0.599218746232+exp(sin((x0-1)))
# 56.97 5.83 0.225506104476*sin((x0+sin((x0-1))))
# 61.87 5.8 0.225506104476*sin((x0-sin((exp(x0))**(-1))))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_squared/feynman_data_KaA1-KeA2.txt_train-add_a
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_squared/feynman_data_KaA1-KeA2.txt_train-add_a
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 46.28 8.18 -0.053521512629*pi
# 49.69 6.3 -0.168142795563+(x0-sin(x0))
# 54.77 5.99 -0.599218746232+exp(sin((x0-1)))
# 56.97 5.83 0.225506104476*sin((x0+sin((x0-1))))
# 61.87 5.8 0.225506104476*sin((x0-sin((exp(x0))**(-1))))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_atan/feynman_data_KaA1-KeA2.txt_train-add_a
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_atan/feynman_data_KaA1-KeA2.txt_train-add_a
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 43.93 21.71 tan(0.833415433764+cos(pi))
# 46.28 8.18 -0.053521512629*pi
# 49.69 6.3 -0.168142795563+(x0-sin(x0))
# 54.77 5.99 -0.599218746232+exp(sin((x0-1)))
# 56.97 5.83 0.225506104476*sin((x0+sin((x0-1))))
# 61.87 5.8 0.225506104476*sin((x0-sin((exp(x0))**(-1))))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_cos/feynman_data_KaA1-KeA2.txt_train-add_a
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_cos/feynman_data_KaA1-KeA2.txt_train-add_a
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 43.93 21.71 tan(0.833415433764+cos(pi))
# 46.28 8.18 -0.053521512629*pi
# 49.69 6.3 -0.168142795563+(x0-sin(x0))
# 54.77 5.99 -0.599218746232+exp(sin((x0-1)))
# 56.97 5.83 0.225506104476*sin((x0+sin((x0-1))))
# 61.87 5.8 0.225506104476*sin((x0-sin((exp(x0))**(-1))))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_exp/feynman_data_KaA1-KeA2.txt_train-add_a
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_exp/feynman_data_KaA1-KeA2.txt_train-add_a
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 43.93 21.71 tan(0.833415433764+cos(pi))
# 46.28 8.18 -0.053521512629*pi
# 49.69 6.3 -0.168142795563+(x0-sin(x0))
# 54.77 5.99 -0.599218746232+exp(sin((x0-1)))
# 56.97 5.83 0.225506104476*sin((x0+sin((x0-1))))
# 61.87 5.8 0.225506104476*sin((x0-sin((exp(x0))**(-1))))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_inverse/feynman_data_KaA1-KeA2.txt_train-add_a
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_inverse/feynman_data_KaA1-KeA2.txt_train-add_a
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 43.93 21.71 tan(0.833415433764+cos(pi))
# 46.28 8.18 -0.053521512629*pi
# 49.69 6.3 -0.168142795563+(x0-sin(x0))
# 54.77 5.99 -0.599218746232+exp(sin((x0-1)))
# 56.97 5.83 0.225506104476*sin((x0+sin((x0-1))))
# 61.87 5.8 0.225506104476*sin((x0-sin((exp(x0))**(-1))))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_sin/feynman_data_KaA1-KeA2.txt_train-add_a
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_sin/feynman_data_KaA1-KeA2.txt_train-add_a
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 43.93 21.71 tan(0.833415433764+cos(pi))
# 46.28 8.18 -0.053521512629*pi
# 49.69 6.3 -0.168142795563+(x0-sin(x0))
# 54.77 5.99 -0.599218746232+exp(sin((x0-1)))
# 56.97 5.83 0.225506104476*sin((x0+sin((x0-1))))
# 61.87 5.8 0.225506104476*sin((x0-sin((exp(x0))**(-1))))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_squared/feynman_data_KaA1-KeA2.txt_train-add_a
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_squared/feynman_data_KaA1-KeA2.txt_train-add_a
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 43.93 21.71 tan(0.833415433764+cos(pi))
# 46.28 8.18 -0.053521512629*pi
# 49.69 6.3 -0.168142795563+(x0-sin(x0))
# 54.77 5.99 -0.599218746232+exp(sin((x0-1)))
# 56.97 5.83 0.225506104476*sin((x0+sin((x0-1))))
# 61.87 5.8 0.225506104476*sin((x0-sin((exp(x0))**(-1))))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_tan/feynman_data_KaA1-KeA2.txt_train-add_a
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_tan/feynman_data_KaA1-KeA2.txt_train-add_a
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 43.93 21.71 tan(0.833415433764+cos(pi))
# 46.28 8.18 -0.053521512629*pi
# 49.69 6.3 -0.168142795563+(x0-sin(x0))
# 54.77 5.99 -0.599218746232+exp(sin((x0-1)))
# 56.97 5.83 0.225506104476*sin((x0+sin((x0-1))))
# 61.87 5.8 0.225506104476*sin((x0-sin((exp(x0))**(-1))))
#
# Just one variable!
# Checking for symmetries...
# feynman_data_KaA1-KeA2.txt_train-add_a just one variable for ADD
#
# feynman_data_KaA1-KeA2.txt_train-add_a just one variable for ADD
#
# feynman_data_KaA1-KeA2.txt_train-add_a just one variable for ADD
#
# feynman_data_KaA1-KeA2.txt_train-add_a just one variable for ADD
#
#
# Checking for separabilities...
# feynman_data_KaA1-KeA2.txt_train-add_a just one variable for ADD
# feynman_data_KaA1-KeA2.txt_train-add_a just one variable for ADD
#
# Checking for compositionality...
#
# Checking for generalized symmetry...
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/separable_add/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/separable_add/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 50.16 26.2 -3.143814802170+pi
# 53.83 23.68 -0.312533145732+(x0/exp(x0))
# 55.36 23.48 -0.452536417893+((x0+(x0)**(-1)))**(-1)
# 56.9 22.69 -0.329283549620+((pi-cos(x0)))**(-1)
# 63.19 20.9 0.525288334321+((sqrt(x0)-pi))**(-1)
# 65.04 19.43 0.169364105263+(x0*cos((((pi)**(-1)-1)-1)))
# 67.58 18.46 0.167766311324+(x0*(sin((sin(log(pi)))**(-1))-1))
# 69.58 18.34 0.167825465842+(x0*(cos((sqrt(exp(pi))+1))-1))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_squared/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_squared/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 43.11 26.24 sqrt(-0.991011636860+((x0*sin(pi))+1))
# 50.16 26.2 -3.143814802170+pi
# 53.83 23.68 -0.312533145732+(x0/exp(x0))
# 55.36 23.48 -0.452536417893+((x0+(x0)**(-1)))**(-1)
# 56.9 22.69 -0.329283549620+((pi-cos(x0)))**(-1)
# 63.19 20.9 0.525288334321+((sqrt(x0)-pi))**(-1)
# 65.04 19.43 0.169364105263+(x0*cos((((pi)**(-1)-1)-1)))
# 67.58 18.46 0.167766311324+(x0*(sin((sin(log(pi)))**(-1))-1))
# 69.58 18.34 0.167825465842+(x0*(cos((sqrt(exp(pi))+1))-1))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_acos/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_acos/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 23.06 30.68 cos(-1.570796414218+pi)
# 43.11 26.24 sqrt(-0.991011636860+((x0*sin(pi))+1))
# 50.16 26.2 -3.143814802170+pi
# 53.83 23.68 -0.312533145732+(x0/exp(x0))
# 55.36 23.48 -0.452536417893+((x0+(x0)**(-1)))**(-1)
# 56.9 22.69 -0.329283549620+((pi-cos(x0)))**(-1)
# 63.19 20.9 0.525288334321+((sqrt(x0)-pi))**(-1)
# 65.04 19.43 0.169364105263+(x0*cos((((pi)**(-1)-1)-1)))
# 67.58 18.46 0.167766311324+(x0*(sin((sin(log(pi)))**(-1))-1))
# 69.58 18.34 0.167825465842+(x0*(cos((sqrt(exp(pi))+1))-1))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_asin/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_asin/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 23.06 30.68 cos(-1.570796414218+pi)
# 37.69 26.21 sin(-3.143814803998+pi)
# 50.16 26.2 -3.143814802170+pi
# 53.83 23.68 -0.312533145732+(x0/exp(x0))
# 55.36 23.48 -0.452536417893+((x0+(x0)**(-1)))**(-1)
# 56.9 22.69 -0.329283549620+((pi-cos(x0)))**(-1)
# 63.19 20.9 0.525288334321+((sqrt(x0)-pi))**(-1)
# 65.04 19.43 0.169364105263+(x0*cos((((pi)**(-1)-1)-1)))
# 67.58 18.46 0.167766311324+(x0*(sin((sin(log(pi)))**(-1))-1))
# 69.18 18.1 sin(0.168727633043+(x0*sin(cos((((pi)**(-1)-1)-1)))))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_atan/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_atan/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 23.06 30.68 cos(-1.570796414218+pi)
# 37.69 26.21 sin(-3.143814803998+pi)
# 37.69 26.2 tan(-3.143814798513+pi)
# 47.15 21.44 tan(0.525167617377+((sqrt(x0)-pi))**(-1))
# 63.19 20.9 0.525288334321+((sqrt(x0)-pi))**(-1)
# 65.04 19.43 0.169364105263+(x0*cos((((pi)**(-1)-1)-1)))
# 67.58 18.46 0.167766311324+(x0*(sin((sin(log(pi)))**(-1))-1))
# 69.18 18.1 sin(0.168727633043+(x0*sin(cos((((pi)**(-1)-1)-1)))))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_cos/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_cos/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 4.0 29.21 acos(-666.000000000000*sin(pi))
# 37.69 26.21 sin(-3.143814803998+pi)
# 37.69 26.2 tan(-3.143814798513+pi)
# 47.15 21.44 tan(0.525167617377+((sqrt(x0)-pi))**(-1))
# 63.19 20.9 0.525288334321+((sqrt(x0)-pi))**(-1)
# 65.04 19.43 0.169364105263+(x0*cos((((pi)**(-1)-1)-1)))
# 67.58 18.46 0.167766311324+(x0*(sin((sin(log(pi)))**(-1))-1))
# 69.18 18.1 sin(0.168727633043+(x0*sin(cos((((pi)**(-1)-1)-1)))))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_exp/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_exp/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 4.0 29.21 acos(-666.000000000000*sin(pi))
# 37.69 26.21 sin(-3.143814803998+pi)
# 37.69 26.2 tan(-3.143814798513+pi)
# 47.15 21.44 tan(0.525167617377+((sqrt(x0)-pi))**(-1))
# 63.19 20.9 0.525288334321+((sqrt(x0)-pi))**(-1)
# 65.04 19.43 0.169364105263+(x0*cos((((pi)**(-1)-1)-1)))
# 67.58 18.46 0.167766311324+(x0*(sin((sin(log(pi)))**(-1))-1))
# 69.18 18.1 sin(0.168727633043+(x0*sin(cos((((pi)**(-1)-1)-1)))))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_inverse/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_inverse/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 4.0 29.21 acos(-666.000000000000*sin(pi))
# 37.69 26.21 sin(-3.143814803998+pi)
# 37.69 26.2 tan(-3.143814798513+pi)
# 47.15 21.44 tan(0.525167617377+((sqrt(x0)-pi))**(-1))
# 63.19 20.9 0.525288334321+((sqrt(x0)-pi))**(-1)
# 65.04 19.43 0.169364105263+(x0*cos((((pi)**(-1)-1)-1)))
# 67.58 18.46 0.167766311324+(x0*(sin((sin(log(pi)))**(-1))-1))
# 69.18 18.1 sin(0.168727633043+(x0*sin(cos((((pi)**(-1)-1)-1)))))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_sin/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_sin/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 4.0 29.21 acos(-666.000000000000*sin(pi))
# 37.69 26.21 sin(-3.143814803998+pi)
# 37.69 26.2 tan(-3.143814798513+pi)
# 47.15 21.44 tan(0.525167617377+((sqrt(x0)-pi))**(-1))
# 63.19 20.9 0.525288334321+((sqrt(x0)-pi))**(-1)
# 65.04 19.43 0.169364105263+(x0*cos((((pi)**(-1)-1)-1)))
# 67.58 18.46 0.167766311324+(x0*(sin((sin(log(pi)))**(-1))-1))
# 69.18 18.1 sin(0.168727633043+(x0*sin(cos((((pi)**(-1)-1)-1)))))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_squared/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_squared/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 4.0 29.21 acos(-666.000000000000*sin(pi))
# 37.69 26.21 sin(-3.143814803998+pi)
# 37.69 26.2 tan(-3.143814798513+pi)
# 47.15 21.44 tan(0.525167617377+((sqrt(x0)-pi))**(-1))
# 63.19 20.9 0.525288334321+((sqrt(x0)-pi))**(-1)
# 65.04 19.43 0.169364105263+(x0*cos((((pi)**(-1)-1)-1)))
# 67.58 18.46 0.167766311324+(x0*(sin((sin(log(pi)))**(-1))-1))
# 69.18 18.1 sin(0.168727633043+(x0*sin(cos((((pi)**(-1)-1)-1)))))
#
# Checking for brute force +
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_tan/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking for brute force *
#
# Trying to solve mysteries with brute force...
# Trying to solve results/mystery_world_tan/feynman_data_KaA1-KeA2.txt_train-add_b
# Checking polyfit
#
# Pareto frontier in the current branch:
#
# Complexity #  MDL Loss #  Expression
# 4.0 29.21 acos(-666.000000000000*sin(pi))
# 37.69 26.21 sin(-3.143814803998+pi)
# 37.69 26.2 tan(-3.143814798513+pi)
# 47.15 21.44 tan(0.525167617377+((sqrt(x0)-pi))**(-1))
# 63.19 20.9 0.525288334321+((sqrt(x0)-pi))**(-1)
# 65.04 19.43 0.169364105263+(x0*cos((((pi)**(-1)-1)-1)))
# 67.58 18.46 0.167766311324+(x0*(sin((sin(log(pi)))**(-1))-1))
# 69.18 18.1 sin(0.168727633043+(x0*sin(cos((((pi)**(-1)-1)-1)))))
#
# Just one variable!
# Checking for symmetries...
# feynman_data_KaA1-KeA2.txt_train-add_b just one variable for ADD
#
# feynman_data_KaA1-KeA2.txt_train-add_b just one variable for ADD
#
# feynman_data_KaA1-KeA2.txt_train-add_b just one variable for ADD
#
# feynman_data_KaA1-KeA2.txt_train-add_b just one variable for ADD
#
#
# Checking for separabilities...
# feynman_data_KaA1-KeA2.txt_train-add_b just one variable for ADD
# feynman_data_KaA1-KeA2.txt_train-add_b just one variable for ADD
#
# Checking for compositionality...
#
# Checking for generalized symmetry...

# %%
# Viewing processed data
# !ls -1 '/content/drive/My Drive/Symbolic-Regressor/Feynman Local/results'
# !cat '/content/drive/My Drive/Symbolic-Regressor/Feynman Local/results/solution_feynman_data_KaA1-KeA2.txt'
# Out:
# gen_sym
# gradients_gen_sym_noisydata.txt_train
# gradients_gen_sym_noisydata.txt_train-translated_plus
# mystery_world_acos
# mystery_world_asin
# mystery_world_atan
# mystery_world_cos
# mystery_world_exp
# mystery_world_inverse
# mystery_world_log
# mystery_world_sin
# mystery_world_sqrt
# mystery_world_squared
# mystery_world_tan
# NN_trained_models
# separable_add
# solution_before_snap_feynman_data_KaA1-KeA2.txt.txt
# solution_before_snap_feynman_data_KaA1.txt.txt
# solution_before_snap_feynman_data_KeA2.txt.txt
# solution_before_snap_feynman_data.txt.txt
# solution_before_snap_noisydata.txt.txt
# solution_feynman_data-finetuning.txt
# solution_feynman_data_KaA1-KeA2.txt
# solution_feynman_data_KaA1.txt
# solution_feynman_data_KeA2.txt
# solution_feynman_data.txt
# solution_first_snap_feynman_data_KaA1-KeA2.txt.txt
# solution_first_snap_feynman_data_KaA1.txt.txt
# solution_first_snap_feynman_data_KeA2.txt.txt
# solution_first_snap_feynman_data.txt.txt
# solution_first_snap_noisydata.txt.txt
# solution_noisydata.txt
# translated_data_minus
# translated_data_multiply
# translated_data_plus
# 28.60086273716262 4.803011368952774 965.4052851595076 27.738593694822818 27.91582657049248 sqrt(0.012099999984*(x0+(x1*(x1+x0))))
# 28.59984879282185 4.802949805611978 965.3929109280076 29.323556195543972 27.914635359024828 sqrt(0.012099999984*((x1+x0)*(x1+x0)))
# 28.601326064698455 4.802666738170254 965.336014372221 30.323556195543972 27.909158838307633 sqrt(0.012099999984*(x0+(x1*(x1*(x0+1)))))
# 6.632128535863507 2.6913392565474576 540.959190566039 34.06727785542857 6.45912731173482 -0.109999999958*(x1-(x0*exp(pi)))
# 6.275906226055803 2.613163385185523 525.2458404222901 38.967412385318696 6.118437985280051 -0.109999999975*(x1-(x0*(exp(pi)+1)))
# 5.606328591105114 2.453162059376381 493.0855739346526 39.55237488603986 5.476150359263951 -0.109999999991*(x1-(x0*((exp(pi)+1)+1)))

# %% [markdown]
# Plotting solution

# %%
def y_soln(x0, x1):
  y = -0.109999999979*(x1-(x0*((jnp.exp(jnp.pi)+1)+1))) #best solution with 10/50 epochs
  return y

# %%
soln = y_soln(data_A1, data_A2)
soln.shape
# Out:
# (201, 1)

# %%
fig = plt.figure(figsize=(15, 3.5))
ax1 = fig.add_subplot(1,2,1)
plt.plot(data_A1, soln, label='Solution')
plt.plot(data_A1, data_y, label='Analytical')
plt.xlabel("A1"); plt.ylabel("y");
plt.title("Solution vs. Analytical with A1"); plt.legend();

ax1 = fig.add_subplot(1,2,2)
plt.plot(data_A2, soln, label='Solution')
plt.plot(data_A2, data_y, label='Analytical')
plt.xlabel("A2"); plt.ylabel("y");

plt.title("Solution vs. Analytical with A2"); plt.legend();
print(df, df.shape)
# Out:
#                 0         1           2
# 0    7.386409e+01  0.000000  208.370599
# 1    5.265214e+01  1.509122  148.365670
# 2    3.753173e+01  2.565072  105.594861
# 3    2.675354e+01  3.298249   75.108928
# 4    1.907058e+01  3.801602   53.379928
# ..            ...       ...         ...
# 196  1.772178e-11  0.414256   -0.045568
# 197  8.033132e-12  0.408824   -0.044971
# 198  7.997448e-12  0.403463   -0.044381
# 199  7.916035e-12  0.398172   -0.043799
# 200  6.091490e-12  0.392950   -0.043225
#
# [201 rows x 3 columns] (201, 3)

# %%
#TODO: mse between SR solution and analytical solution
print(soln.shape, data_y.shape)
jnp.mean(jnp.square(soln - data_y))
# Out:
# (201, 1) (201, 1)
# Array(0.17012532, dtype=float64)
