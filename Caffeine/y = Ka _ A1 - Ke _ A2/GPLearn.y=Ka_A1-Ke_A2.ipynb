# %% [markdown]
# Data Visualization

# %%
import jax
import flax
import optax
from jax import lax, random, numpy as jnp
from jax import random, grad, vmap, hessian, jacfwd, jit
from jax import config
from flax import linen as nn
from scipy.integrate import odeint

import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# choose GPU
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
jax.config.update("jax_enable_x64", True)

# %%
# !pip install evojax
from evojax.util import get_params_format_fn
# Out:
# Collecting evojax
#   Downloading evojax-0.2.17-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: flax in /usr/local/lib/python3.10/dist-packages (from evojax) (0.8.4)
# Requirement already satisfied: jax>=0.2.17 in /usr/local/lib/python3.10/dist-packages (from evojax) (0.4.26)
# Requirement already satisfied: jaxlib>=0.1.65 in /usr/local/lib/python3.10/dist-packages (from evojax) (0.4.26+cuda12.cudnn89)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from evojax) (9.4.0)
# Collecting cma (from evojax)
#   Downloading cma-3.4.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from evojax) (3.7.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from evojax) (6.0.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.2.17->evojax) (0.2.0)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from jax>=0.2.17->evojax) (1.25.2)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax>=0.2.17->evojax) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from jax>=0.2.17->evojax) (1.11.4)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from flax->evojax) (1.0.8)
# Requirement already satisfied: optax in /usr/local/lib/python3.10/dist-packages (from flax->evojax) (0.2.2)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.10/dist-packages (from flax->evojax) (0.4.4)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.10/dist-packages (from flax->evojax) (0.1.45)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.10/dist-packages (from flax->evojax) (13.7.1)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.10/dist-packages (from flax->evojax) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->evojax) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax->evojax) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax->evojax) (2.16.1)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from optax->flax->evojax) (1.4.0)
# Requirement already satisfied: chex>=0.1.86 in /usr/local/lib/python3.10/dist-packages (from optax->flax->evojax) (0.1.86)
# Requirement already satisfied: etils[epath,epy] in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax->evojax) (1.7.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax->evojax) (1.6.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax->evojax) (3.20.3)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chex>=0.1.86->optax->flax->evojax) (0.12.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax->evojax) (0.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->evojax) (2023.6.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->evojax) (6.4.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->evojax) (3.19.2)
# Downloading evojax-0.2.17-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.1/96.1 kB 1.7 MB/s eta 0:00:00
# Downloading cma-3.4.0-py3-none-any.whl (269 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.7/269.7 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: cma, evojax
# Successfully installed cma-3.4.0 evojax-0.2.17

# %%
#true params
Ka_true = 2.821 # 1/h - not in spreadsheet
Ke_true = 0.693/6.3 # 1/h
V_blood_true = 19 # L
V_gut_true = 1.3612 # L
dosage_true = 100.5348 #mg, just for reference

# %%
#initial conditions
A1_init = 73.864090508375 # / V_gut_true # (mg/L) #needs to be decided
A2_init = 0 # (mg/L)

# %%
# task array
task_params = np.array([[Ka_true, Ke_true, V_gut_true, V_blood_true]])

n_task = len(task_params)
n_task, task_params
# Out:
# (1, array([[ 2.821 ,  0.11  ,  1.3612, 19.    ]]))

# %% [markdown]
# Obtaining Ground Truth

# %%
#caffeine equation solution generator
def caffeine(y, t, Ka, Ke, V_gut, V_blood):
    """A1 and A2 terms are not divided by V, they are just divided before being plotted"""
    A1_sys, A2_sys = y
    dydt = [-Ka* (A1_sys), Ka*(A1_sys) - Ke*(A2_sys)]
    return dydt

# %%
data_A1, data_A2, data_S = [], [], [] #collect all 6 tasks (different combination of a1 a2) #data S is all zeroes
t = jnp.linspace(0, 24, 201)
t_param = t #copy for calculating ODE
t = np.expand_dims(t, axis=1) #for data_X

data_T = t
for task in task_params:

    y0 = [A1_init * V_gut_true, A2_init * V_blood_true] #must scale A1 and A2 if all resulting A1/A2 values are divided by V

    #get ODE soln for A2
    sol = odeint(caffeine, y0, t_param, args=(Ka_true, Ke_true, V_gut_true, V_blood_true))
    A1_soln = sol[:, 0:1]
    A2_soln = sol[:, 1:2]

    #divide all values by V
    data_A2.append(A2_soln/V_blood_true)
    data_A1.append(A1_soln/V_gut_true)

    #init an array of zeroes for g
    s_array = np.zeros(len(A2_soln))
    s_array = np.expand_dims(s_array, axis=1)
    data_S.append(s_array)

data_A1, data_A2, data_S = jnp.array(data_A1[0]), jnp.array(data_A2[0]), jnp.array(data_S[0])
data_y = Ka_true * data_A1 - Ke_true * data_A2
print (data_T.shape, data_A1.shape, data_A2.shape, data_S.shape, data_y.shape)
# Out:
# (201, 1) (201, 1) (201, 1) (201, 1) (201, 1)

# %%
fig = plt.figure(figsize=(15, 3.5))
ax1 = fig.add_subplot(1,2,1)


params = task_params[0]
plt.plot(data_T, data_A1, label='Ka = %.2f, Ke = %.2f, V1 = %.2f, V2 = %.2f'%(params[0], params[1], params[2], params[3]))
plt.plot(data_T, data_y, label='y = Ka*A1 - Ke*A2')

plt.title("A1 vs. time - New Equation"); plt.legend();
plt.xlabel("Time"); plt.ylabel("A1");
ax1 = fig.add_subplot(1,2,2)


params = task_params[0]
plt.plot(data_T, data_A2, label='Ka = %.2f, Ke = %.2f, V1 = %.2f, V2 = %.2f'%(params[0], params[1], params[2], params[3]))
plt.plot(data_T, data_y, label='y = Ka*A1 - Ke*A2')

    # plt.plot(data_T, data_A2_csv[0], label='CSV data')
plt.title("A2 vs. time - New Equation"); plt.legend();
plt.xlabel("Time"); plt.ylabel("A2")
# Out:
# Text(0, 0.5, 'A2')

# %% [markdown]
# ## GPLearn

# %% [markdown]
# **Mount colab notebook to Drive**

# %%
# Mounting colab notebook to Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# *Downloading gplearn and relevant packages*

# %%
# Installing gplearn
# https://gplearn.readthedocs.io/en/stable/installation.html
# !pip install gplearn
# Out:
# Collecting gplearn
#   Downloading gplearn-0.4.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from gplearn) (1.2.2)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gplearn) (1.4.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->gplearn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->gplearn) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->gplearn) (3.5.0)
# Downloading gplearn-0.4.2-py3-none-any.whl (25 kB)
# Installing collected packages: gplearn
# Successfully installed gplearn-0.4.2

# %% [markdown]
# *Importing relevant modules/functions*

# %%
# %pylab inline
from gplearn.genetic import SymbolicRegressor
# import matplotlib as plt
import numpy as np
import pandas as pd
import os
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %% [markdown]
# *Verify working directory*

# %%
input_path = '/content/drive/My Drive/Symbolic-Regressor/Feynman Local/Caffeine/Text Files/'
os.chdir(input_path)
# !pwd
# Out:
# /content/drive/My Drive/Symbolic-Regressor/Feynman Local/Caffeine/Text Files

# %% [markdown]
# Perfect data - generation, plotting, symbolic regression

# %%
#Generating data sets compatible with PySR wagwarn bot dat dign
x_values = jnp.hstack([data_A1, data_A2])
y_values = data_y[:,0]

np.save('x_values_gplearn_A1A2.npy',x_values)
np.savetxt('x_values_gplearn_A1A2.txt',x_values,delimiter=' ')

np.save('y_values_gplearn_KaA1-KeA2.npy',y_values)
np.savetxt('y_values_gplearn_KaA1-KeA2.txt',y_values,delimiter=' ')

# Converting data into a .txt format compatible with matplotlib (for plotting step)
with open('xy_data_gplearn_y=KaA1-KeA2.txt', 'w') as f:
  for r in range(201):
    f.write(f'{x_values[:, 0][r]} {x_values[:, 1][r]} {y_values[r]}\n')

# %%
# Printing perfect data with Pandas and plotting it with matplotlib
df=pd.read_csv(input_path + 'xy_data_gplearn_y=KaA1-KeA2.txt',sep=" ",header=None)

fig = plt.figure(figsize=(15, 3.5))
ax1 = fig.add_subplot(1,2,1)
plt.plot(df[0], df[2], label='A1 vs y')
plt.xlabel("A1"); plt.ylabel("y");
plt.title("A1 vs. y data"); plt.legend();

ax1 = fig.add_subplot(1,2,2)
plt.plot(df[1], df[2], label='A2 vs y')
plt.xlabel("A2"); plt.ylabel("y");

plt.title("A2 vs. y data"); plt.legend();
print(df, df.shape)
# Out:
#                 0         1           2
# 0    7.386409e+01  0.000000  208.370599
# 1    5.265214e+01  1.509122  148.365670
# 2    3.753173e+01  2.565072  105.594861
# 3    2.675354e+01  3.298249   75.108928
# 4    1.907058e+01  3.801602   53.379928
# ..            ...       ...         ...
# 196  1.772178e-11  0.414256   -0.045568
# 197  8.033132e-12  0.408824   -0.044971
# 198  7.997448e-12  0.403463   -0.044381
# 199  7.916035e-12  0.398172   -0.043799
# 200  6.091490e-12  0.392950   -0.043225
#
# [201 rows x 3 columns] (201, 3)

# %%
# Running gplearn symbolic regression on perfect data (default settings)
est_gp = SymbolicRegressor(population_size=1000,
                           generations=100, stopping_criteria=0.001,
                           p_crossover=0.7, p_subtree_mutation=0.1,
                           p_hoist_mutation=0.05, p_point_mutation=0.1,
                           max_samples=0.9, verbose=1,
                           parsimony_coefficient=0.01, random_state=0)
est_gp.fit(x_values, y_values)
print(est_gp._program)

# The smaller the dataset, population_size can be increased. If the known target equation is (relatively) simple, parsimony_coefficient can be increased.
# https://github.com/trevorstephens/gplearn/blob/master/gplearn/genetic.py
# Out:
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0    38.53      1.94636e+08       15          1.04451          11.6226      4.50m
#    1    12.90          671.623        9         0.434711         0.448022      1.39m
#    2     8.81          13481.1       19         0.271995         0.148669      1.26m
#    3     6.51          36.3929        7         0.240977          1.21395      1.17m
#    4     6.44          240.818        7         0.232105             1.29      1.20m
#    5     6.95          26.2587        9         0.227833          0.75744      1.22m
#    6     7.28          4.87673        9         0.200234         0.993996      1.15m
#    7     7.79          643.768        9         0.191522          1.06867      1.26m
#    8     7.95          140.632        9         0.155389         0.902113      2.24m
#    9     8.15          3.80603        9         0.170368             1.25      1.70m
#   10     8.69          3.16005       11         0.118347         0.119345      1.79m
#   11     8.98          8.16338       11         0.118464         0.118339      1.38m
#   12     9.00          31.4309       11         0.115439         0.144272      1.10m
#   13     9.50          10.7641       11         0.109889         0.191844      1.12m
#   14    10.77          745.326       11          0.11054         0.186258      1.12m
#   15    10.88          205.772       11          0.11181         0.175378      1.11m
#   16    11.05          139.633       11         0.111142         0.181097      1.14m
#   17    10.97          5.16563       11         0.109073         0.198832      1.12m
#   18    11.09          4.91014       11         0.109995          0.19093      1.13m
#   19    10.74          4.23398       11         0.108476         0.203947      1.09m
#   20    10.91          3.75189       11          0.11002         0.190717      1.03m
#   21    10.77          6.84253       11         0.111153         0.181005      1.07m
#   22    10.87          53.3923       11         0.109796         0.192634      1.04m
#   23    11.05          11.5692       11         0.107749         0.210182      1.22m
#   24    10.78          3.22138       11         0.109915         0.191616      1.51m
#   76    10.67          34.7184       11         0.110461         0.186936     20.59s
#   77    10.87          270.161       11         0.112197         0.172058     19.18s
#   78    10.68          5.80762       11         0.108784         0.201313     18.47s
#   79    10.84          5.78588       11         0.110793         0.184088     17.81s
#   80    10.88          4.78146       11         0.109751         0.193025     16.68s
#   81    11.07          3.99583       11         0.110111         0.189938     15.70s
#   82    10.82          7.58932       11         0.109527         0.194939     21.64s
#   83    10.62          4.24928       11         0.109973         0.191117     19.90s
#   84    10.70          13.9419       11         0.111271         0.179992     19.45s
#   85    11.23          14211.5       11         0.109539         0.194836     17.71s
#   86    10.89          4.05733       11         0.110048         0.190473     11.08s
#   87    10.99          4.45736       11         0.109905         0.191705     10.68s
#   88    10.76          4.95517       11         0.109615         0.194191     10.49s
#   89    11.10          1179.29       11         0.108039           0.2077      8.74s
#   90    11.10          7.12072       11         0.109895         0.191792      7.77s
#   91    11.06          27.2852       11         0.109102          0.19859      7.19s
#   92    10.96          14.8167       11         0.108416         0.204467      6.47s
#   93    10.75           9.9071       11         0.110597         0.185774      5.32s
#   94    11.29          2546.12       11         0.111035         0.182015      4.31s
#   95    10.76          9.24035       11          0.11163         0.176915      3.61s
#   96    10.79          19.8847       11         0.109263         0.197208      3.18s
#   97    10.75          39.1862       11         0.110071         0.190277      2.57s
#   98    10.97          14.1728       11          0.11053         0.186345      1.29s
#   99    11.09          9.94704       11         0.109001         0.199453      0.00s
# add(X0, add(add(X0, mul(0.661, div(X0, 0.816))), -0.157))

# %% [markdown]
# Plotting solution

# %%
def y_soln(x0, x1):
  return (x0 + 0.661*(x0/0.816)) - 0.157

# %%
soln = y_soln(data_A1, data_A2)
soln.shape
# Out:
# (201, 1)

# %%
fig = plt.figure(figsize=(7.5, 3.5))

fig = plt.figure(figsize=(15, 3.5))
ax1 = fig.add_subplot(1,2,1)
plt.plot(data_A1, soln, label='Solution')
plt.plot(data_A1, data_y, label='Analytical')
plt.xlabel("A1"); plt.ylabel("y");
plt.title("Solution vs. Analytical with A1"); plt.legend();

ax1 = fig.add_subplot(1,2,2)
plt.plot(data_A2, soln, label='Solution')
plt.plot(data_A2, data_y, label='Analytical')
plt.xlabel("A2"); plt.ylabel("y");

plt.title("Solution vs. Analytical with A2"); plt.legend();
print(df, df.shape)
# Out:
#                 0         1           2
# 0    7.386409e+01  0.000000  208.370599
# 1    5.265214e+01  1.509122  148.365670
# 2    3.753173e+01  2.565072  105.594861
# 3    2.675354e+01  3.298249   75.108928
# 4    1.907058e+01  3.801602   53.379928
# ..            ...       ...         ...
# 196  1.772178e-11  0.414256   -0.045568
# 197  8.033132e-12  0.408824   -0.044971
# 198  7.997448e-12  0.403463   -0.044381
# 199  7.916035e-12  0.398172   -0.043799
# 200  6.091490e-12  0.392950   -0.043225
#
# [201 rows x 3 columns] (201, 3)

# %%
#TODO: mse between SR solution and analytical solution
print(soln.shape, data_y.shape)
jnp.mean(jnp.square(soln - data_y))
# Out:
# (201, 1) (201, 1)
# Array(56.22427679, dtype=float64)
