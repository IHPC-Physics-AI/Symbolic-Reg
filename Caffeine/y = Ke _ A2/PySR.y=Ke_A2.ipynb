# %% [markdown]
# Data Visualization

# %%
import jax
import flax
import optax
from jax import lax, random, numpy as jnp
from jax import random, grad, vmap, hessian, jacfwd, jit
from jax import config
from flax import linen as nn
from scipy.integrate import odeint

import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# choose GPU
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
jax.config.update("jax_enable_x64", True)

# %%
# !pip install evojax
from evojax.util import get_params_format_fn
# Out:
# Collecting evojax
#   Downloading evojax-0.2.17-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: flax in /usr/local/lib/python3.10/dist-packages (from evojax) (0.8.4)
# Requirement already satisfied: jax>=0.2.17 in /usr/local/lib/python3.10/dist-packages (from evojax) (0.4.26)
# Requirement already satisfied: jaxlib>=0.1.65 in /usr/local/lib/python3.10/dist-packages (from evojax) (0.4.26+cuda12.cudnn89)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from evojax) (9.4.0)
# Collecting cma (from evojax)
#   Downloading cma-3.4.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from evojax) (3.7.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from evojax) (6.0.2)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.2.17->evojax) (0.4.0)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from jax>=0.2.17->evojax) (1.26.4)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax>=0.2.17->evojax) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from jax>=0.2.17->evojax) (1.13.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from flax->evojax) (1.0.8)
# Requirement already satisfied: optax in /usr/local/lib/python3.10/dist-packages (from flax->evojax) (0.2.2)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.10/dist-packages (from flax->evojax) (0.5.23)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.10/dist-packages (from flax->evojax) (0.1.64)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.10/dist-packages (from flax->evojax) (13.7.1)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.10/dist-packages (from flax->evojax) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->evojax) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->evojax) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax->evojax) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax->evojax) (2.16.1)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from optax->flax->evojax) (1.4.0)
# Requirement already satisfied: chex>=0.1.86 in /usr/local/lib/python3.10/dist-packages (from optax->flax->evojax) (0.1.86)
# Requirement already satisfied: etils[epath,epy] in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax->evojax) (1.7.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax->evojax) (1.6.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax->evojax) (3.20.3)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chex>=0.1.86->optax->flax->evojax) (0.12.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax->evojax) (0.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->evojax) (2024.6.1)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->evojax) (6.4.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax->evojax) (3.20.0)
# Downloading evojax-0.2.17-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.1/96.1 kB 2.1 MB/s eta 0:00:00
# Downloading cma-3.4.0-py3-none-any.whl (269 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.7/269.7 kB 8.6 MB/s eta 0:00:00
# Installing collected packages: cma, evojax
# Successfully installed cma-3.4.0 evojax-0.2.17

# %%
#true params
Ka_true = 2.821 # 1/h - not in spreadsheet
Ke_true = 0.693/6.3 # 1/h
V_blood_true = 19 # L
V_gut_true = 1.3612 # L
dosage_true = 100.5348 #mg, just for reference

# %%
#initial conditions
A1_init = 73.864090508375 # / V_gut_true # (mg/L) #needs to be decided
A2_init = 0 # (mg/L)

# %%
# task array
# Ka_params = jnp.linspace(1., 10., 5)
# Ke_params = jnp.linspace(0.0001, 1., 5)
# V_gut_params = jnp.linspace(0.5, 2.5, 5) #cannot divide by 0, trying to only predict blood for now #V1
# V_blood_params = jnp.linspace(10., 25., 5) #cannot divide by 0, trying to only predict blood for now #V2

# task_params = jnp.stack((Ka_params, Ke_params, V_gut_params, V_blood_params), axis=1)

task_params = np.array([[Ka_true, Ke_true, V_gut_true, V_blood_true]])

n_task = len(task_params)
n_task, task_params
# Out:
# (1, array([[ 2.821 ,  0.11  ,  1.3612, 19.    ]]))

# %% [markdown]
# Obtaining Ground Truth

# %%
#caffeine equation solution generator
def caffeine(y, t, Ka, Ke, V_gut, V_blood):
    """A1 and A2 terms are not divided by V, they are just divided before being plotted"""
    A1_sys, A2_sys = y
    dydt = [-Ka* (A1_sys), Ka*(A1_sys) - Ke*(A2_sys)]
    return dydt

# %%
data_A1, data_A2, data_S = [], [], [] #collect all 6 tasks (different combination of a1 a2) #data S is all zeroes
t = jnp.linspace(0, 24, 201)
t_param = t #copy for calculating ODE
t = np.expand_dims(t, axis=1) #for data_X

data_T = t
for task in task_params:

    y0 = [A1_init * V_gut_true, A2_init * V_blood_true] #must scale A1 and A2 if all resulting A1/A2 values are divided by V

    #get ODE soln for A2
    sol = odeint(caffeine, y0, t_param, args=(Ka_true, Ke_true, V_gut_true, V_blood_true))
    A1_soln = sol[:, 0:1]
    A2_soln = sol[:, 1:2]

    #divide all values by V
    data_A2.append(A2_soln/V_blood_true)
    data_A1.append(A1_soln/V_gut_true)

    #init an array of zeroes for g
    s_array = np.zeros(len(A2_soln))
    s_array = np.expand_dims(s_array, axis=1)
    data_S.append(s_array)

data_A1, data_A2, data_S = jnp.array(data_A1[0]), jnp.array(data_A2[0]), jnp.array(data_S[0])
data_y = data_A2 * Ke_true
print (data_T.shape, data_A1.shape, data_A2.shape, data_S.shape, data_y.shape)
# Out:
# (201, 1) (201, 1) (201, 1) (201, 1) (201, 1)

# %%
fig = plt.figure(figsize=(15, 3.5))
ax1 = fig.add_subplot(1,2,1)


params = task_params[0]
plt.plot(data_T, data_A1, label='Ka = %.2f, Ke = %.2f, V1 = %.2f, V2 = %.2f'%(params[0], params[1], params[2], params[3]))
# plt.plot(data_T, data_A1_csv[0], label='CSV data')

plt.title("A1 vs. time - New Equation"); plt.legend();
plt.xlabel("Time"); plt.ylabel("A1");
ax1 = fig.add_subplot(1,2,2)


params = task_params[0]
plt.plot(data_T, data_A2, label='Ka = %.2f, Ke = %.2f, V1 = %.2f, V2 = %.2f'%(params[0], params[1], params[2], params[3]))
plt.plot(data_T, data_y, label='Ke * A2')

    # plt.plot(data_T, data_A2_csv[0], label='CSV data')
plt.title("A2 vs. time - New Equation"); plt.legend();
plt.xlabel("Time"); plt.ylabel("A2")
# Out:
# Text(0, 0.5, 'A2')

# %% [markdown]
# ## PySR

# %% [markdown]
# **Mounting colab notebook to Drive**

# %%
# Mounting colab notebook to drive
from google.colab import drive
drive.mount('/content/drive')
import pickle
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Julia installation (run once)**

# %%
# Julia installation
# %%shell
set -e

#---------------------------------------------------#
JULIA_VERSION="1.6.0" # any version ≥ 0.7.0
JULIA_PACKAGES="IJulia BenchmarkTools Plots"
JULIA_PACKAGES_IF_GPU="CUDA" # or CuArrays for older Julia versions
JULIA_NUM_THREADS=2
#---------------------------------------------------#

if [ -n "$COLAB_GPU" ] && [ -z `which julia` ]; then
  # Install Julia
  JULIA_VER=`cut -d '.' -f -2 <<< "$JULIA_VERSION"`
  echo "Installing Julia $JULIA_VERSION on the current Colab Runtime..."
  BASE_URL="https://julialang-s3.julialang.org/bin/linux/x64"
  URL="$BASE_URL/$JULIA_VER/julia-$JULIA_VERSION-linux-x86_64.tar.gz"
  wget -nv $URL -O /tmp/julia.tar.gz # -nv means "not verbose"
  tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
  rm /tmp/julia.tar.gz

  # Install Packages
  if [ "$COLAB_GPU" = "1" ]; then
      JULIA_PACKAGES="$JULIA_PACKAGES $JULIA_PACKAGES_IF_GPU"
  fi
  for PKG in `echo $JULIA_PACKAGES`; do
    echo "Installing Julia package $PKG..."
    julia -e 'using Pkg; pkg"add '$PKG'; precompile;"' &> /dev/null
  done

  # Install kernel and rename it to "julia"
  echo "Installing IJulia kernel..."
  julia -e 'using IJulia; IJulia.installkernel("julia", env=Dict(
      "JULIA_NUM_THREADS"=>"'"$JULIA_NUM_THREADS"'"))'
  KERNEL_DIR=`julia -e "using IJulia; print(IJulia.kerneldir())"`
  KERNEL_NAME=`ls -d "$KERNEL_DIR"/julia*`
  mv -f $KERNEL_NAME "$KERNEL_DIR"/julia

  echo ''
  echo "Success! Please reload this page and jump to the next section."
fi

# %% [markdown]
# *Installing PySR and relevant packages*

# %%
# Installing PySR (and relevant packages)
# !pip install pysr
# Out:
# Requirement already satisfied: pysr in /usr/local/lib/python3.10/dist-packages (0.19.3)
# Requirement already satisfied: sympy<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pysr) (1.13.1)
# Requirement already satisfied: pandas<3.0.0,>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from pysr) (2.0.3)
# Requirement already satisfied: numpy<3.0.0,>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from pysr) (1.25.2)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pysr) (1.2.2)
# Requirement already satisfied: juliacall==0.9.21 in /usr/local/lib/python3.10/dist-packages (from pysr) (0.9.21)
# Requirement already satisfied: click<9.0.0,>=7.0.0 in /usr/local/lib/python3.10/dist-packages (from pysr) (8.1.7)
# Requirement already satisfied: setuptools>=50.0.0 in /usr/local/lib/python3.10/dist-packages (from pysr) (71.0.4)
# Requirement already satisfied: juliapkg~=0.1.8 in /usr/local/lib/python3.10/dist-packages (from juliacall==0.9.21->pysr) (0.1.13)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=0.21.0->pysr) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=0.21.0->pysr) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=0.21.0->pysr) (2024.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.0.0->pysr) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.0.0->pysr) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.0.0->pysr) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy<2.0.0,>=1.0.0->pysr) (1.3.0)
# Requirement already satisfied: semver~=3.0 in /usr/local/lib/python3.10/dist-packages (from juliapkg~=0.1.8->juliacall==0.9.21->pysr) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=0.21.0->pysr) (1.16.0)

# %% [markdown]
# *Importing relevant modules*

# %%
#Importing relevant modules
import os
# import matplotlib as plt
import pandas as pd
import numpy as np
from pysr import pysr, best, PySRRegressor

# %% [markdown]
# *Verifying working directory*

# %%
input_path = '/content/drive/My Drive/Symbolic-Regressor/Feynman Local/Caffeine/Text Files/'
os.chdir(input_path)
# !pwd
# Out:
# /content/drive/My Drive/Symbolic-Regressor/Feynman Local/Caffeine/Text Files

# %% [markdown]
# *Perfect data - generation, plotting, symbolic regression*

# %%
#Generating data sets compatible with PySR wagwarn bot dat dign
x_values = jnp.hstack([data_A1, data_A2])
y_values = data_y[:, 0]

np.save('x_values_pysr_A1A2.npy',x_values)
np.savetxt('x_values_pysr_A1A2.txt',x_values,delimiter=' ')

np.save('y_values_pysr_KeA2.npy',y_values)
np.savetxt('y_values_pysr_KeA2.txt',y_values,delimiter=' ')

# Converting data into a .txt format compatible with matplotlib (for plotting step)
with open('xy_data_pysr_y=KeA2.txt', 'w') as f:
  for r in range(201):
    f.write(f'{x_values[:, 0][r]} {x_values[:, 1][r]} {y_values[r]}\n')

# %%
# Printing perfect data with Pandas and plotting it with matplotlib
df=pd.read_csv(input_path + 'xy_data_pysr_y=KeA2.txt',sep=" ",header=None)

fig = plt.figure(figsize=(7.5, 3.5))

plt.plot(df[1], df[2], label='A2 vs y')

plt.title("A2 vs. y data"); plt.legend();
plt.xlabel("A2"); plt.ylabel("y");
print(df, df.shape)
# Out:
#                 0         1         2
# 0    7.386409e+01  0.000000  0.000000
# 1    5.265214e+01  1.509122  0.166003
# 2    3.753173e+01  2.565072  0.282158
# 3    2.675354e+01  3.298249  0.362807
# 4    1.907058e+01  3.801602  0.418176
# ..            ...       ...       ...
# 196  1.772178e-11  0.414256  0.045568
# 197  8.033132e-12  0.408824  0.044971
# 198  7.997448e-12  0.403463  0.044381
# 199  7.916035e-12  0.398172  0.043799
# 200  6.091490e-12  0.392950  0.043225
#
# [201 rows x 3 columns] (201, 3)

# %%
for num_iters in [10]: #, 30, 60, 80, 100 #for loop for hyperparameter tuning
    model = PySRRegressor(
        niterations=num_iters,  # < Increase me for better results
        binary_operators=["+", "*", "-", "/"],
        unary_operators=[
            "sign",
            "neg",
            "cos",
            "exp",
            "sin",  # Pre-defined library of operators (see docs)
            "inv(x) = 1/x",  # Define your own operator! (Julia syntax)
        ],
        extra_sympy_mappings={"inv": lambda x: 1 / x},
        # ^ Define operator for SymPy as well
        elementwise_loss="loss(prediction, target) = (prediction - target)^2",
        # ^ Custom loss function (julia syntax)
    )

    print(model.fit(x_values, y_values))
    #for saving the model
    # model_path = input_path + 'data/model-%2d.pkl'%(num_iters)

    # with open(model_path, 'wb') as file:
    #   pickle.dump(model, file)
# Out:
# /usr/local/lib/python3.10/dist-packages/pysr/sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 1.860e+04
# Head worker occupation: 38.3%
# Progress: 39 / 150 total iterations (26.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.985e-02  7.971e+00  y = sin(0.20455)
# 4           1.061e-04  2.616e+00  y = sin(x₁ * 0.10823)
# 5           5.856e-05  5.946e-01  y = (0.12681 * x₁) * 0.84059
# 6           1.284e-05  1.517e+00  y = sin((x₁ * 0.12889) * 0.87321)
# 7           3.116e-06  1.416e+00  y = (x₁ / exp(1.9977)) * sin(0.95574)
# 8           2.316e-06  2.964e-01  y = sin(sin(1.2148)) * (x₁ / exp(1.9977))
# 10          5.898e-14  7.874e+00  y = sin(sin(cos(3.0382 / 3.3515))) * (x₁ / 4.9681)
# 13          1.384e-16  2.018e+00  y = (x₁ * neg(-0.83835 * (0.12651 + 0.004705))) / sign(sign(ex...
#                                   p(0.007087)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.210e+04
# Head worker occupation: 36.5%
# Progress: 100 / 150 total iterations (66.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.985e-02  7.971e+00  y = sin(0.20455)
# 3           1.189e-15  1.594e+01  y = 0.11 * x₁
# 4           1.384e-16  2.151e+00  y = neg(-0.11 * x₁)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.260e+04
# Head worker occupation: 33.9%
# Progress: 148 / 150 total iterations (98.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 2           1.985e-02  7.971e+00  y = sin(0.20455)
# 3           1.189e-15  1.594e+01  y = 0.11 * x₁
# 4           1.384e-16  2.151e+00  y = neg(-0.11 * x₁)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	   pick      score          equation          loss  complexity
# 	0         0.000000   sin(0.20455289)  1.984861e-02           2
# 	1        30.445867  0.110000014 * x1  1.189209e-15           3
# 	2  >>>>   2.150660   neg(-0.11 * x1)  1.384327e-16           4
# ]

# %%
print(model.sympy()) #get best fit expression
# Out:
# 0.11*x1

# %% [markdown]
# Plotting solution

# %%
def y_soln(x0, x1):
  return x1*0.11

# %%
soln = y_soln(data_A1, data_A2)
soln.shape
# Out:
# (201, 1)

# %%
fig = plt.figure(figsize=(7.5, 3.5))

params = task_params[0]
plt.plot(data_A2, soln, label='Solution')
plt.plot(data_A2, data_y, label='Analytical')
# plt.plot(data_T, data_A1_csv[0], label='CSV data')

plt.title("PySR: Solution vs. Analytical: Ke * A2"); plt.legend();
plt.xlabel("A1"); plt.ylabel("y");

# %%
#TODO: mse between SR solution and analytical solution
print(soln.shape, data_y.shape)
jnp.mean(jnp.square(soln - data_y))
# Out:
# (201, 1) (201, 1)
# Array(0., dtype=float64)
